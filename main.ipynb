# %%
import pandas as pd
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Load data
data = pd.read_csv("student_habits_performance.csv", index_col = "student_id")
data
# Out:
#             age  gender  study_hours_per_day  social_media_hours  \
# student_id
# S1000        23  Female                  0.0                 1.2
# S1001        20  Female                  6.9                 2.8
# S1002        21    Male                  1.4                 3.1
# S1003        23  Female                  1.0                 3.9
# S1004        19  Female                  5.0                 4.4
# ...         ...     ...                  ...                 ...
# S1995        21  Female                  2.6                 0.5
# S1996        17  Female                  2.9                 1.0
# S1997        20    Male                  3.0                 2.6
# S1998        24    Male                  5.4                 4.1
# S1999        19  Female                  4.3                 2.9
#
#             netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# student_id
# S1000                 1.1            No                   85.0          8.0
# ...

# %%
# Check for na values
print(data.isna().sum())
# Out:
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
# View how NA data is stored
print(data[data["parental_education_level"].isna()])
# Out:
#             age  gender  study_hours_per_day  social_media_hours  \
# student_id
# S1010        19  Female                  4.6                 3.7
# S1033        18  Female                  4.0                 0.9
# S1047        23  Female                  2.5                 2.9
# S1074        21  Female                  2.3                 1.0
# S1093        22    Male                  4.1                 2.5
# ...         ...     ...                  ...                 ...
# S1921        23  Female                  4.4                 2.7
# S1925        19   Other                  1.7                 2.9
# S1939        18  Female                  4.7                 3.2
# S1945        23    Male                  6.0                 2.9
# S1967        22    Male                  5.2                 4.1
#
#             netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# student_id
# S1010                 0.8            No                   77.6          5.8
# ...
